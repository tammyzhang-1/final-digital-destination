# %%
import pandas as pd
import numpy as np
import json
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
data = pd.read_csv("original_data.csv")
data
# Out:
#     Unnamed: 0                                        Unnamed: 1  \
# 0      TABLE 1                                               NaN
# 1          NaN                                               NaN
# 2            #                                     Company\nName
# 3            1                                   1 Green\nPlanet
# 4            2                                       Accurate IT
# ..         ...                                               ...
# 168         86                                    Urban\nRenewal
# 169         87                Valley City\nElectronic\nRecycling
# 170         88                                 Windfield\nAlloy*
# 171         89  WTB Elec-\ntronics Recy-\ncling Import\n& Export
# 172         90                  Yesterday's\nBusiness\nComputers
#
#                                  Unnamed: 2                     Unnamed: 3  \
# 0                                       NaN                            NaN
# 1                                       NaN                            NaN
# 2                                  Location  Position\non Chain of\nExport
# 3                                Renton, WA                          First
# 4                              Columbus, OH                First and\nLast
# ..                                      ...                            ...
# 168                              Kerney, NY                          First
# 169                            Kentwood, MI                          First
# 170                            Lawrence, NH                          First
# 171  Santa Ana, CA\n33.747121,\n-117.897295                           Last
# 172                       Hillsborough,\nNJ                First and\nLast
#
#                            Unnamed: 4                     Unnamed: 5  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2    Device\nExported,\nDevice Number  Certi at\ntime of\npossession
# 3                       LCD\nWA546164                           None
# 4                       CRT\nOH157467                             R2
# ..                                ...                            ...
# 168                     LCD\nNJ615555         None\n(Previously\nR2)
# 169                 Printer\nMI157079                             R2
# 170                     CRT\nNH356259                    e-Stewards*
# 171                     LCD\nCA549390                           None
# 172                 Printer\nNJ615662         None\n(Previously\nR2)
#
#        Unnamed: 6                                      Unnamed: 7  \
# 0             NaN                                             NaN
# 1             NaN                                             NaN
# 2    ISRI\nMember                                 State\nProgram1
# 3              No                                              No
# 4              No                        N/A No\nstate pro-\ngram
# ..            ...                                             ...
# 168            No  Yes Small\nQuantity\nUniversal\nWaste\nHandler
# 169            No                     Yes Reg-\nistered\nrecycler
# 170            No                        N/A No\nstate pro-\ngram
# 171            No                           Yes Active\ncollector
# 172            No                                              No
#
#                                             Unnamed: 8     Unnamed: 9  \
# 0                                                  NaN            NaN
# 1                                                  NaN            NaN
# 2                          Misrepresentation\nConcern2  EPA Mentions3
# 3                                                  Yes             No
# 4    No\n(But discusses BAN's\nfindings of pollutio...            Yes
# ..                                                 ...            ...
# 168                                                 No             No
# 169  Yes\n(R2 PDF saying they\ncomply with all inte...             No
# 170                                                 No            Yes
# 171                                                 No             No
# 172                                                 No             No
#
#                                            Unnamed: 10  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                        Last location
# 3                          Hong Kong, New\nTerritories
# 4                                     Pakistan, Multan
# ..                                                 ...
# 168  Dominican\nRepublic,\nSantiago de los\nCaballeros
# 169                                    China, Shangqiu
# 170                                      China, Foshan
# 171                         Cambodia,\nPhnom Penh area
# 172                        Hong Kong, New\nTerritories
#
#                                            Unnamed: 11
# 0                                                  NaN
# 1                                                  NaN
# 2                              Chain of Export Summary
# 3    1. 1 Green Planet\n2. EWC Group Recyclers/eWas...
# 4    1. Accurate IT\n2. Pakistan, Port Qasim\n3. Pa...
# ..                                                 ...
# 168  1. Urban Renewal\n2. East Orange, NJ area 40.7...
# 169  1. Valley City Electronic Recycling\n2. Unveri...
# 170  1. Windfield Alloy\n2. Unverified location, Do...
# 171  1. Recycling Event at Eliot Middle School, Alt...
# 172  1. Yesterday's Business Computers\n2. Port New...
#
# [173 rows x 12 columns]

# %%
devices = pd.read_csv("devices.csv")
devices["certification"] = devices["certification"].replace({np.nan:"None"})
devices.to_json("devices.json", orient = "records" )

# %%
nodes = pd.read_csv("nodes.csv")

# %%
feature_collection_template = {"type": "FeatureCollection" }
def create_feature(row):
    coordinates = json.loads(row["coordinates"])
    return {
        "type": "Feature",
        "geometry": {"type": "Point", "coordinates": coordinates},
        "properties": {
            "id": row["id"],
            "device_id": row["device_id"],
            "name": row["name"],
            "precise": row["precise"]
        }
    }

feature_collection = nodes.apply(create_feature, axis=1).tolist()
feature_collection_template["features"] = feature_collection
feature_json = feature_collection_template
with open("nodes.geojson", "w") as f:
    json.dump(feature_json, f)

# %%
nodes
# Out:
#     device_id  id                                               name  \
# 0    WA546164   1                                     1 Green Planet
# 1    WA546164   2                  EWC Group Recyclers/eWaste Center
# 2    WA546164   3                        Canada, Vancouver Port area
# 3    WA546164   4                       Hong Kong, Port of Hong Kong
# 4    WA546164   5                         Hong Kong, New Territories
# 5    OH157467   6                                        Accurate IT
# 6    OH157467   7                               Pakistan, Port Qasim
# 7    OH157467   8                                  Pakistan, Multan
# 8    MA352894   9                              ACT Secured Recycling
# 9    MA352894  10                                     TBS Industries
# 10   MA352894  11                      Hong Kong, Port of Hong Kong
# 11   MA352894  12                        Hong Kong, New Territories
# 12   NV353413  13                             Nevada State Recycling
# 13   NV353413  14                                       TW Recycling
# 14   NV353413  15                               Advance Trading Corp
# 15   NV353413  16                      Hong Kong, Port of Hong Kong
# 16   NV353413  17                        Hong Kong, New Territories
# 17   CA549390  18             Recycling Event at Eliot Middle School
# 18   CA549390  19                               Attan Recycling Corp
# 19   CA549390  20                              Advance Trading Corp
# 20   CA549390  21          WTB Electronics Recycling Import & Export
# 21   CA549390  22                                 Port of Long Beach
# 22   CA549390  23  Cambodia, Unverified location (Krong Preah Sih...
# 23   CA549390  24    Cambodia, Unverified location (Phnom Penh area)
# 24   NJ614731  25                        Advanced Recovery Inc (ARI)
# 25   NJ614731  26                Unverified location, Middletown, NJ
# 26   NJ614731  27                       Hong Kong, Port of Hong Kong
# 27   NJ614731  28                         Hong Kong, New Territories
# 28   CA552709  29                           AERC Recycling Solutions
# 29   CA552709  30                 Unverified location, Stockton, CA
# 30   CA552709  31                Unverified location, Chino, CA area
# 31   CA552709  32                     Hong Kong - Port of Hong Kong
# 32   CA552709  33                Hong Kong - Pillar Point port area
# 33   CA552709  34                        Hong Kong, New Territories
# 34   CA552709  35                        Hong Kong, New Territories
# 35   CA552709  36                        Hong Kong, New Territories
# 36  CCA545745  37   All eWaste collection event in Santa Clarita, CA
# 37  CCA545745  38  All eWaste HQ, Sun Valley, CA (34.228201, -118...
# 38  CCA545745  39                                        IQA Metals
# 39  CCA545745  40                                Port of Long Beach
# 40  CCA545745  41                      Hong Kong, Port of Hong Kong
# 41  CCA545745  42                        Hong Kong, New Territories
# 42   MA616330  43                            Allied Computer Brokers
# 43   MA616330  44          Unverified location, North Billerica, MA
# 44   MA616330  45                 Unverified location in Boston, MA
# 45   MA616330  46                       Hong Kong, Port of Hong Kong
# 46   MA616330  47   Hong Kong, New Territories (unverified location)
# 47   MA616330  48                        Hong Kong, New Territories
# 48   IL163523  49                                              ARCOA
# 49   IL163523  50                                         ECR World
# 50   IL163523  51                             Port of Long Beach, CA
# 51   IL163523  52                      Hong Kong, Port of Hong Kong
# 52   IL163523  53                        Hong Kong, New Territories
#
#                                   coordinates  precise
# 0    [-122.19699064903253, 47.49902565156954]        1
# 1    [-122.23015963874957, 47.39918336447823]        1
# 2   [-123.10969537747143, 49.311940748353905]        0
# 3                     [114.133333, 22.333333]        0
# 4                         [114.1234, 22.3704]        0
# 5    [-83.10375272549389, 39.969208831162504]        1
# 6     [67.32869344511904, 24.767448330394107]        0
# 7                      [71.456527, 30.188337]        1
# 8     [-71.15304421041003, 42.70884038245311]        1
# 9    [-72.71720745007592, 42.255490525325705]        1
# 10                    [114.133333, 22.333333]        0
# 11                    [113.981538, 22.453303]        1
# 12  [-115.16180688119586, 36.149843415024044]        1
# 13                       [-115.1391, 36.1716]        0
# 14                   [-117.659313, 34.059492]        1
# 15                    [114.133333, 22.333333]        0
# 16                    [114.019274, 22.423244]        1
# 17   [-118.13098919025249, 34.18319568783581]        1
# 18   [-117.70934439496996, 34.00004410331367]        1
# 19                   [-117.659305, 34.059311]        1
# 20   [-117.89691402570422, 33.74740440684496]        1
# 21    [-118.2164027066185, 33.75403604662242]        0
# 22   [103.50137915753281, 10.642753097996945]        0
# 23   [104.91787357108755, 11.569222198370339]        0
# 24    [-74.1433280275119, 40.800374754822016]        1
# 25   [-74.09835253992611, 40.390667496929424]        0
# 26                    [114.133333, 22.333333]        0
# 27                    [114.166662, 22.526796]        1
# 28   [-122.05533117717962, 37.61812962397873]        1
# 29  [-121.29412056429278, 37.957938447355495]        0
# 30  [-117.68712989747965, 34.011361309491235]        0
# 31                    [114.133333, 22.333333]        0
# 32     [113.9390984215767, 22.36470542117652]        0
# 33                     [114.071367, 22.48509]        1
# 34                     [114.01992, 22.455738]        1
# 35                    [114.003833, 22.485871]        1
# 36    [-118.541739267885, 34.393247873697874]        0
# 37                   [-118.385998, 34.228201]        1
# 38    [-117.6895369240572, 33.99408744384333]        1
# 39    [-118.2164027066185, 33.75403604662242]        0
# 40                    [114.133333, 22.333333]        0
# 41                      [113.9652, 22.447456]        1
# 42     [-70.94801096873985, 42.8424297205171]        1
# 43      [-71.284720026298, 42.58325368671266]        0
# 44    [-71.05973740671557, 42.36045887721905]        0
# 45                    [114.133333, 22.333333]        0
# 46                        [114.1234, 22.3704]        0
# 47                    [113.987362, 22.453112]        1
# 48    [-87.88251900807431, 42.36075574682718]        1
# 49   [-117.69497257795065, 33.99177714145301]        1
# 50    [-118.2164027066185, 33.75403604662242]        0
# 51                    [114.133333, 22.333333]        0
# 52                    [114.002787, 22.436384]        1

# %%
feature_collection_template2 = {"type": "FeatureCollection" }

def test(df):
    return df.iloc[:-1].apply(create_feature2, axis=1)

def create_feature2(row):
    next_row_index = row["id"] + 1
    
    if next_row_index < len(nodes) + 1:
        next_row = nodes.iloc[next_row_index - 1]
        next_coordinates = json.loads(next_row["coordinates"])
        coordinates = json.loads(row["coordinates"])
        
        # check if points are in similar region (don't cross if in same area)
        if coordinates[0] * next_coordinates[0] > 0:
            cross = 0
        # cross if leaving from east coast of US
        if -66 < coordinates[0] < -100 and next_coordinates[0] * coordinates[0] <
        0:
        else:
            cross = 1
        
        cross = 0 if (coordinates[0] * next_coordinates[0] > 0 and coordinates[0] < -100) else 1
        
        return { "type": "Feature",
          "geometry": {
            "type": "LineString",
            "coordinates": [coordinates, next_coordinates]
            },
          "properties": {
            "device_id": row["device_id"],
            "source_id": int(row["id"]),
            "target_id": int(next_row["id"]),
            "cross": cross
            }
          }
    return None

# %%
edges_unfiltered = nodes.groupby("device_id", as_index=False).apply(test).tolist()

# %%
edges_unfiltered
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.13098919025249, 34.18319568783581],
#     [-117.70934439496996, 34.00004410331367]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 18,
#    'target_id': 19,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.70934439496996, 34.00004410331367],
#     [-117.659305, 34.059311]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 19,
#    'target_id': 20,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.659305, 34.059311],
#     [-117.89691402570422, 33.74740440684496]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 20,
#    'target_id': 21,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.89691402570422, 33.74740440684496],
#     [-118.2164027066185, 33.75403604662242]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 21,
#    'target_id': 22,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.2164027066185, 33.75403604662242],
#     [103.50137915753281, 10.642753097996945]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 22,
#    'target_id': 23,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[103.50137915753281, 10.642753097996945],
#     [104.91787357108755, 11.569222198370339]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 23,
#    'target_id': 24,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-122.05533117717962, 37.61812962397873],
#     [-121.29412056429278, 37.957938447355495]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 29,
#    'target_id': 30,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-121.29412056429278, 37.957938447355495],
#     [-117.68712989747965, 34.011361309491235]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 30,
#    'target_id': 31,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.68712989747965, 34.011361309491235],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 31,
#    'target_id': 32,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333],
#     [113.9390984215767, 22.36470542117652]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 32,
#    'target_id': 33,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[113.9390984215767, 22.36470542117652],
#     [114.071367, 22.48509]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 33,
#    'target_id': 34,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.071367, 22.48509], [114.01992, 22.455738]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 34,
#    'target_id': 35,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.01992, 22.455738], [114.003833, 22.485871]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 35,
#    'target_id': 36,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.541739267885, 34.393247873697874],
#     [-118.385998, 34.228201]]},
#   'properties': {'device_id': 'CCA545745',
#    'source_id': 37,
#    'target_id': 38,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.385998, 34.228201],
#     [-117.6895369240572, 33.99408744384333]]},
#   'properties': {'device_id': 'CCA545745',
#    'source_id': 38,
#    'target_id': 39,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.6895369240572, 33.99408744384333],
#     [-118.2164027066185, 33.75403604662242]]},
#   'properties': {'device_id': 'CCA545745',
#    'source_id': 39,
#    'target_id': 40,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.2164027066185, 33.75403604662242],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'CCA545745',
#    'source_id': 40,
#    'target_id': 41,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [113.9652, 22.447456]]},
#   'properties': {'device_id': 'CCA545745',
#    'source_id': 41,
#    'target_id': 42,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-87.88251900807431, 42.36075574682718],
#     [-117.69497257795065, 33.99177714145301]]},
#   'properties': {'device_id': 'IL163523',
#    'source_id': 49,
#    'target_id': 50,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.69497257795065, 33.99177714145301],
#     [-118.2164027066185, 33.75403604662242]]},
#   'properties': {'device_id': 'IL163523',
#    'source_id': 50,
#    'target_id': 51,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.2164027066185, 33.75403604662242],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'IL163523',
#    'source_id': 51,
#    'target_id': 52,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [114.002787, 22.436384]]},
#   'properties': {'device_id': 'IL163523',
#    'source_id': 52,
#    'target_id': 53,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-71.15304421041003, 42.70884038245311],
#     [-72.71720745007592, 42.255490525325705]]},
#   'properties': {'device_id': 'MA352894',
#    'source_id': 9,
#    'target_id': 10,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-72.71720745007592, 42.255490525325705],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'MA352894',
#    'source_id': 10,
#    'target_id': 11,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [113.981538, 22.453303]]},
#   'properties': {'device_id': 'MA352894',
#    'source_id': 11,
#    'target_id': 12,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-70.94801096873985, 42.8424297205171],
#     [-71.284720026298, 42.58325368671266]]},
#   'properties': {'device_id': 'MA616330',
#    'source_id': 43,
#    'target_id': 44,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-71.284720026298, 42.58325368671266],
#     [-71.05973740671557, 42.36045887721905]]},
#   'properties': {'device_id': 'MA616330',
#    'source_id': 44,
#    'target_id': 45,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-71.05973740671557, 42.36045887721905],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'MA616330',
#    'source_id': 45,
#    'target_id': 46,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [114.1234, 22.3704]]},
#   'properties': {'device_id': 'MA616330',
#    'source_id': 46,
#    'target_id': 47,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.1234, 22.3704], [113.987362, 22.453112]]},
#   'properties': {'device_id': 'MA616330',
#    'source_id': 47,
#    'target_id': 48,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-74.1433280275119, 40.800374754822016],
#     [-74.09835253992611, 40.390667496929424]]},
#   'properties': {'device_id': 'NJ614731',
#    'source_id': 25,
#    'target_id': 26,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-74.09835253992611, 40.390667496929424],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'NJ614731',
#    'source_id': 26,
#    'target_id': 27,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [114.166662, 22.526796]]},
#   'properties': {'device_id': 'NJ614731',
#    'source_id': 27,
#    'target_id': 28,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-115.16180688119586, 36.149843415024044],
#     [-115.1391, 36.1716]]},
#   'properties': {'device_id': 'NV353413',
#    'source_id': 13,
#    'target_id': 14,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-115.1391, 36.1716], [-117.659313, 34.059492]]},
#   'properties': {'device_id': 'NV353413',
#    'source_id': 14,
#    'target_id': 15,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.659313, 34.059492], [114.133333, 22.333333]]},
#   'properties': {'device_id': 'NV353413',
#    'source_id': 15,
#    'target_id': 16,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [114.019274, 22.423244]]},
#   'properties': {'device_id': 'NV353413',
#    'source_id': 16,
#    'target_id': 17,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-83.10375272549389, 39.969208831162504],
#     [67.32869344511904, 24.767448330394107]]},
#   'properties': {'device_id': 'OH157467',
#    'source_id': 6,
#    'target_id': 7,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[67.32869344511904, 24.767448330394107],
#     [71.456527, 30.188337]]},
#   'properties': {'device_id': 'OH157467',
#    'source_id': 7,
#    'target_id': 8,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-122.19699064903253, 47.49902565156954],
#     [-122.23015963874957, 47.39918336447823]]},
#   'properties': {'device_id': 'WA546164',
#    'source_id': 1,
#    'target_id': 2,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-122.23015963874957, 47.39918336447823],
#     [-123.10969537747143, 49.311940748353905]]},
#   'properties': {'device_id': 'WA546164',
#    'source_id': 2,
#    'target_id': 3,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-123.10969537747143, 49.311940748353905],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'WA546164',
#    'source_id': 3,
#    'target_id': 4,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [114.1234, 22.3704]]},
#   'properties': {'device_id': 'WA546164',
#    'source_id': 4,
#    'target_id': 5,
#    'cross': 1}}]

# %%
edges = [i for i in edges_unfiltered if i is not None]

# %%
edges
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.13098919025249, 34.18319568783581],
#     [-117.70934439496996, 34.00004410331367]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 18,
#    'target_id': 19,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.70934439496996, 34.00004410331367],
#     [-117.659305, 34.059311]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 19,
#    'target_id': 20,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.659305, 34.059311],
#     [-117.89691402570422, 33.74740440684496]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 20,
#    'target_id': 21,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.89691402570422, 33.74740440684496],
#     [-118.2164027066185, 33.75403604662242]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 21,
#    'target_id': 22,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.2164027066185, 33.75403604662242],
#     [103.50137915753281, 10.642753097996945]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 22,
#    'target_id': 23,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[103.50137915753281, 10.642753097996945],
#     [104.91787357108755, 11.569222198370339]]},
#   'properties': {'device_id': 'CA549390',
#    'source_id': 23,
#    'target_id': 24,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-122.05533117717962, 37.61812962397873],
#     [-121.29412056429278, 37.957938447355495]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 29,
#    'target_id': 30,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-121.29412056429278, 37.957938447355495],
#     [-117.68712989747965, 34.011361309491235]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 30,
#    'target_id': 31,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.68712989747965, 34.011361309491235],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 31,
#    'target_id': 32,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333],
#     [113.9390984215767, 22.36470542117652]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 32,
#    'target_id': 33,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[113.9390984215767, 22.36470542117652],
#     [114.071367, 22.48509]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 33,
#    'target_id': 34,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.071367, 22.48509], [114.01992, 22.455738]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 34,
#    'target_id': 35,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.01992, 22.455738], [114.003833, 22.485871]]},
#   'properties': {'device_id': 'CA552709',
#    'source_id': 35,
#    'target_id': 36,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.541739267885, 34.393247873697874],
#     [-118.385998, 34.228201]]},
#   'properties': {'device_id': 'CCA545745',
#    'source_id': 37,
#    'target_id': 38,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.385998, 34.228201],
#     [-117.6895369240572, 33.99408744384333]]},
#   'properties': {'device_id': 'CCA545745',
#    'source_id': 38,
#    'target_id': 39,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.6895369240572, 33.99408744384333],
#     [-118.2164027066185, 33.75403604662242]]},
#   'properties': {'device_id': 'CCA545745',
#    'source_id': 39,
#    'target_id': 40,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.2164027066185, 33.75403604662242],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'CCA545745',
#    'source_id': 40,
#    'target_id': 41,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [113.9652, 22.447456]]},
#   'properties': {'device_id': 'CCA545745',
#    'source_id': 41,
#    'target_id': 42,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-87.88251900807431, 42.36075574682718],
#     [-117.69497257795065, 33.99177714145301]]},
#   'properties': {'device_id': 'IL163523',
#    'source_id': 49,
#    'target_id': 50,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.69497257795065, 33.99177714145301],
#     [-118.2164027066185, 33.75403604662242]]},
#   'properties': {'device_id': 'IL163523',
#    'source_id': 50,
#    'target_id': 51,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-118.2164027066185, 33.75403604662242],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'IL163523',
#    'source_id': 51,
#    'target_id': 52,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [114.002787, 22.436384]]},
#   'properties': {'device_id': 'IL163523',
#    'source_id': 52,
#    'target_id': 53,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-71.15304421041003, 42.70884038245311],
#     [-72.71720745007592, 42.255490525325705]]},
#   'properties': {'device_id': 'MA352894',
#    'source_id': 9,
#    'target_id': 10,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-72.71720745007592, 42.255490525325705],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'MA352894',
#    'source_id': 10,
#    'target_id': 11,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [113.981538, 22.453303]]},
#   'properties': {'device_id': 'MA352894',
#    'source_id': 11,
#    'target_id': 12,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-70.94801096873985, 42.8424297205171],
#     [-71.284720026298, 42.58325368671266]]},
#   'properties': {'device_id': 'MA616330',
#    'source_id': 43,
#    'target_id': 44,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-71.284720026298, 42.58325368671266],
#     [-71.05973740671557, 42.36045887721905]]},
#   'properties': {'device_id': 'MA616330',
#    'source_id': 44,
#    'target_id': 45,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-71.05973740671557, 42.36045887721905],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'MA616330',
#    'source_id': 45,
#    'target_id': 46,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [114.1234, 22.3704]]},
#   'properties': {'device_id': 'MA616330',
#    'source_id': 46,
#    'target_id': 47,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.1234, 22.3704], [113.987362, 22.453112]]},
#   'properties': {'device_id': 'MA616330',
#    'source_id': 47,
#    'target_id': 48,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-74.1433280275119, 40.800374754822016],
#     [-74.09835253992611, 40.390667496929424]]},
#   'properties': {'device_id': 'NJ614731',
#    'source_id': 25,
#    'target_id': 26,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-74.09835253992611, 40.390667496929424],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'NJ614731',
#    'source_id': 26,
#    'target_id': 27,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [114.166662, 22.526796]]},
#   'properties': {'device_id': 'NJ614731',
#    'source_id': 27,
#    'target_id': 28,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-115.16180688119586, 36.149843415024044],
#     [-115.1391, 36.1716]]},
#   'properties': {'device_id': 'NV353413',
#    'source_id': 13,
#    'target_id': 14,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-115.1391, 36.1716], [-117.659313, 34.059492]]},
#   'properties': {'device_id': 'NV353413',
#    'source_id': 14,
#    'target_id': 15,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-117.659313, 34.059492], [114.133333, 22.333333]]},
#   'properties': {'device_id': 'NV353413',
#    'source_id': 15,
#    'target_id': 16,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [114.019274, 22.423244]]},
#   'properties': {'device_id': 'NV353413',
#    'source_id': 16,
#    'target_id': 17,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-83.10375272549389, 39.969208831162504],
#     [67.32869344511904, 24.767448330394107]]},
#   'properties': {'device_id': 'OH157467',
#    'source_id': 6,
#    'target_id': 7,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[67.32869344511904, 24.767448330394107],
#     [71.456527, 30.188337]]},
#   'properties': {'device_id': 'OH157467',
#    'source_id': 7,
#    'target_id': 8,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-122.19699064903253, 47.49902565156954],
#     [-122.23015963874957, 47.39918336447823]]},
#   'properties': {'device_id': 'WA546164',
#    'source_id': 1,
#    'target_id': 2,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-122.23015963874957, 47.39918336447823],
#     [-123.10969537747143, 49.311940748353905]]},
#   'properties': {'device_id': 'WA546164',
#    'source_id': 2,
#    'target_id': 3,
#    'cross': 0}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-123.10969537747143, 49.311940748353905],
#     [114.133333, 22.333333]]},
#   'properties': {'device_id': 'WA546164',
#    'source_id': 3,
#    'target_id': 4,
#    'cross': 1}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[114.133333, 22.333333], [114.1234, 22.3704]]},
#   'properties': {'device_id': 'WA546164',
#    'source_id': 4,
#    'target_id': 5,
#    'cross': 1}}]

# %%
# edges = nodes.groupby("device_id", as_index=False).apply(test).iloc[0, 1:-1].tolist()

# %%
feature_collection_template = {"type": "FeatureCollection" }
feature_collection_template["features"] = edges
feature_json = feature_collection_template
with open("edges.geojson", "w") as f:
    json.dump(feature_json, f)
